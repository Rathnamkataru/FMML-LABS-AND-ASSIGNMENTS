# %% [markdown]
# <a href="https://colab.research.google.com/github/Rathnamkataru/FMML-LABS-AND-ASSIGNMENTS/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-06 18:42:14--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   124MB/s    in 0.6s
#
# 2024-04-06 18:42:18 (124 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 35564   0904.2953v1  Making a decision in a changeable and dynamic ...    cs
# 34447  1608.07094v2  In this paper, we introduce a new measure call...    cs
# 22322  1602.00229v1  Most signal processing problems involve the ch...  stat
# 2499    1409.0791v1  Map matching of the GPS trajectory serves the ...  stat
# 19770   1207.1381v1  We present a framework to discover and charact...    cs
# ...             ...                                                ...   ...
# 7688   1802.08626v1  We address the problem of algorithmic fairness...  stat
# 26974  1701.06462v1  In this paper we propose a supervised learning...    cs
# 960    1503.02031v1  Training deep belief networks (DBNs) requires ...    cs
# 19058   1301.7405v1  This paper presents two new approaches to deco...    cs
# 2497    1404.5214v1  We propose a representation of graph as a func...    cs
#
#                                                    title  year  \
# 35564  Towards an Intelligent System for Risk Prevent...  2009
# 34447  A Novel Term_Class Relevance Measure for Text ...  2016
# 22322  Iterative Gaussianization: from ICA to Random ...  2016
# 2499   Feature Selection in Conditional Random Fields...  2014
# 19770  Unsupervised Activity Discovery and Characteri...  2012
# ...                                                  ...   ...
# 7688   Empirical Risk Minimization under Fairness Con...  2018
# 26974  Using Convolutional Neural Networks to Count P...  2017
# 960    To Drop or Not to Drop: Robustness, Consistenc...  2015
# 19058  Flexible Decomposition Algorithms for Weakly C...  2013
# 2497              Graph Kernels via Functional Embedding  2014
#
#                                                 keywords
# 35564  [changeable, environment, information, uncerta...
# 34447  [introduce, relevance, relevancy, classifying,...
# 22322  [processing, challenging, multidimensional, pr...
# 2499   [trajectory, recovering, observations, fundame...
# 19770  [framework, characterize, different, activitie...
# ...                                                  ...
# 7688   [algorithmic, sensitive, variables, influence,...
# 26974  [supervised, localizing, resolution, panchroma...
# 960    [optimizing, extremely, parameters, naturally,...
# 19058  [approaches, decomposing, decoupling, decoupli...
# 2497   [representation, functional, iteration, underl...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 35564    [changeable, environment, information, uncerta...
# 34447    [introduce, relevance, relevancy, classifying,...
# 22322    [processing, challenging, multidimensional, pr...
# 2499     [trajectory, recovering, observations, fundame...
# 19770    [framework, characterize, different, activitie...
#                                ...
# 15271    [developers, specifically, identifiers, implem...
# 4617     [hierarchical, classification, addresses, clas...
# 22012    [stochastic, coordinate, technique, regularize...
# 22681    [reproducing, associated, divergence, conditio...
# 6570     [structured, prediction, expressive, structure...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8786 words.
# Out of those 4603 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="33741929-4e25-4b18-a1fe-14eca3335a0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33741929-4e25-4b18-a1fe-14eca3335a0d")) {                    Plotly.newPlot(                        "33741929-4e25-4b18-a1fe-14eca3335a0d",                        [{"x":["environment","representation","evolution","emergency","unawareness","efficient","architecture","management","uncertainties","intelligent","monitoring","incidents","prevention","interested","information","classifying","newsgroups","population","categorization","superiority","introduce","conducted","documents","experimentation","significance","occurrence","estimates","particular","unlabeled","comparative","weighting","relevancy","relevance","participation","demonstrate","containing","classification","theoretically","differentiability","algorithms","transform","estimated","difference","convergence","synthesis","performance","iterative","orthonormal","qualitative","convenient","denoising","multivariate","differentiable","sequential","rotations","classical","illustrated","practical","procedure","application","projection","experimentally","estimation","successfully","processing","challenging","framework","convenience","transforms","univariate","interestingness","multidimensional","probability","invertibility","description","covariance","trajectories","complexity","trajectory","selection","observations","characteristics","conditional","computation","fundamental","competitive","experiments","contextual","technique","recovering","applications","discovered","activities","recurrent","unsupervised","representing","collected","different","extensive","generalizability","discovery","competence","structural","undirected","statistics","characterization","environments","characterize","unprecedented","stability","formulate","precision","functions","independent","generalization","projected","interests","dimensional","subspaces","supervised","exploiting","algorithm","optimization","developing","naturally","correlation","optimized","uncertainty","decisions","underlying","outperforms","cumulative","empirically","assumptions","introducing","minimizes","empirical","asymptotic","processes","optimizing","nevertheless","metareasoning","achieving","evaluation","therefore","techniques","retrieving","containment","algorithmic","improvement","experimental","adversely","asymmetric","implement","retrieval","resemblance","estimating","significantly","evaluations","monotonic","transformations","available","traditional","collision","approaches","suboptimal","desirable","theoretical","penalization","literature","comparisons","statistically","advantages","efficiently","inference","variables","combination","regression","nonlinear","computationally","establish","parametric","described","dimensions","generalized","particularities","binarization","segmentation","extraction","applicable","demonstrates","descriptor","identification","extending","heuristics","promising","difficult","restrictive","optimality","computational"],"y":[111,344,70,3,2,386,235,46,14,72,31,3,5,29,681,38,1,48,27,35,331,78,84,14,18,23,70,278,44,57,17,2,36,6,519,50,496,41,3,591,58,59,53,116,47,891,73,3,57,15,39,18,17,77,9,107,25,145,106,254,62,42,201,81,305,255,529,4,19,6,1,21,178,1,74,23,18,216,16,153,81,84,89,144,83,138,586,39,226,20,420,23,34,145,173,74,75,766,158,3,56,5,73,11,52,26,80,50,7,34,58,81,228,132,105,17,15,180,27,203,70,791,316,48,54,67,46,85,64,134,259,9,77,56,48,25,160,11,91,57,18,2,83,258,137,357,11,2,43,132,347,2,12,77,128,8,68,253,44,21,41,292,163,4,414,9,35,143,1,115,32,26,84,167,189,118,144,122,45,80,50,33,66,36,73,2,6,197,122,42,52,28,98,25,41,105,145,10,25,324],"type":"bar"},{"x":["environment","representation","evolu ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4603,), (4603, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Revision</span> <span style=''>Based</span> <span style=''>Approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>Resolving</span> <span style='background-color:rgba(0, 255, 0, 0.7647058823529411);'>Conflicting</span> <span style='background-color:rgba(0, 255, 0, 0.3108758421559192);'>Information</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>revision</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>conflict</span> <span style='background-color:rgba(0, 255, 0, 0.6216216216216217);'>resolution</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Disjunctive</span> <span style=''>Maxi</span> <span style='background-color:rgba(0, 255, 0, 0.75);'>Adjustment</span> <span style=''>(DMA)</span> <span style=''>approach</span> <span style=''>(Benferhat</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2004)</span> <span style=''>Revision</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>operators</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classified</span> <span style=''>into</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.336823734729494);'>different</span> <span style=''>families</span> <span style=''>the</span> <span style=''>model</span> <span style=''>based</span> <span style=''>ones</span> <span style=''>and</span> <span style=''>the</span> <span style=''>formula</span> <span style=''>based</span> <span style=''>ones</span> <span style=''>So</span> <span style=''>the</span> <span style=''>revision</span> <span style=''>based</span> <span style=''>approach</span> <span style=''>has</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.336823734729494);'>different</span> <span style=''>versions</span> <span style='background-color:rgba(0, 255, 0, 0.4305555555555556);'>according</span> <span style=''>to</span> <span style=''>which</span> <span style=''>family</span> <span style=''>of</span> <span style=''>revision</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>operators</span> <span style=''>is</span> <span style=''>chosen</span> <span style=''>Two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>revision</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>operators</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>one</span> <span style=''>is</span> <span style=''>the</span> <span style=''>Dalals</span> <span style=''>revision</span> <span style=''>operator</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>model</span> <span style=''>based</span> <span style=''>revision</span> <span style=''>operator</span> <span style=''>and</span> <span style=''>the</span> <span style=''>other</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cardinality</span> <span style=''>maximal</span> <span style=''>based</span> <span style=''>revision</span> <span style=''>operator</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>formulabased</span> <span style=''>revision</span> <span style=''>operator</span> <span style=''>When</span> <span style=''>the</span> <span style=''>Dalals</span> <span style=''>revision</span> <span style=''>operator</span> <span style=''>is</span> <span style=''>chosen</span> <span style=''>the</span> <span style=''>r ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Laplacian</span> <span style=''>eigenfunction</span> <span style=''>maps</span> <br/><br/><span style=''>Any</span> <span style=''>closed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connected</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Riemannian</span> <span style=''>manifold</span> <span style=''>M</span> <span style=''>can</span> <span style=''>be</span> <span style=''>smoothly</span> <span style=''>embedded</span> <span style=''>by</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Laplacian</span> <span style=''>eigenfunction</span> <span style=''>maps</span> <span style=''>into</span> <span style=''>mathbbRm</span> <span style=''>for</span> <span style=''>some</span> <span style=''>m</span> <span style=''>We</span> <span style=''>call</span> <span style=''>the</span> <span style=''>smallest</span> <span style=''>such</span> <span style=''>m</span> <span style=''>the</span> <span style=''>maximal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>M</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>maximal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>M</span> <span style=''>is</span> <span style=''>bounded</span> <span style=''>from</span> <span style=''>above</span> <span style=''>by</span> <span style=''>a</span> <span style=''>constant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>depending</span> <span style=''>only</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>M</span> <span style=''>a</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>for</span> <span style=''>injectivity</span> <span style=''>radius</span> <span style=''>a</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>for</span> <span style=''>Ricci</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>curvature</span> <span style=''>and</span> <span style=''>a</span> <span style=''>volume</span> <span style=''>bound</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpret</span> <span style=''>this</span> <span style=''>result</span> <span style=''>for</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>surfaces</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>isometrically</span> <span style=''>immersed</span> <span style=''>in</span> <span style=''>mathbbR3</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>the</span> <span style=''>maximal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>only</span> <span style=''>depends</span> <span style=''>on</span> <span style=''>bounds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>curvature</span> <span style=''>mean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>curvature</span> <span style=''>and</span> <span style=''>surface</span> <span style=''>area</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>the</span> <span style='backgr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Herding</span> <span style=''>Dynamic</span> <span style=''>Weights</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Partially</span> <span style=''>Observed</span> <span style=''>Random</span> <span style=''>Field</span> <span style=''>Models</span> <br/><br/><span style=''>Learning</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>a</span> <span style=''>(potentially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style=''>observable)</span> <span style=''>random</span> <span style=''>field</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.4929577464788732);'>intractable</span> <span style=''>in</span> <span style=''>general</span> <span style=''>Instead</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>focussing</span> <span style=''>on</span> <span style=''>a</span> <span style=''>single</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>value</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>treat</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dynamical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantities</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>complex</span> <span style=''>dynamics</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>and</span> <span style=''>(both</span> <span style=''>visible</span> <span style=''>and</span> <span style=''>hidden)</span> <span style=''>state</span> <span style=''>vectors</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>under</span> <span style=''>certain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>averages</span> <span style=''>computed</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>trajectories</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dynamical</span> <span style=''>system</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>averages</span> <span style=''>computed</span> <span style=''>over</span> <span style=''>the</span> <span style=''>data</span> <span style=''>Our</span> <span style=''>herding</span> <span style=''>dynamics</span> <span style=''>does</span> <span style=''>not</span> <span style=''>require</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style='background-color:rgba(0, 255, 0, 0.4956521739130435);'>operations</span> <span style=''>such</span> <span style=''>as</span> <span style=''>exponentiation</span> <span style=''>and</span> <span style=''>is</span> <span style=''>fully</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deterministic</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Mathematical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Formalization</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style=''>Temporal</span> <span style=''>Memorys</span> <span style=''>Spatial</span> <span style=''>Pooler</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style=''>temporal</span> <span style=''>memory</span> <span style=''>(HTM)</span> <span style=''>is</span> <span style=''>an</span> <span style=''>emerging</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>means</span> <span style=''>to</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>spatiotemporal</span> <span style=''>data</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neocortex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>currently</span> <span style=''>does</span> <span style=''>not</span> <span style=''>have</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comprehensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mathematical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>This</span> <span style=''>work</span> <span style=''>brings</span> <span style=''>together</span> <span style=''>all</span> <span style=''>aspects</span> <span style=''>of</span> <span style=''>the</span> <span style=''>spatial</span> <span style=''>pooler</span> <span style=''>(SP)</span> <span style=''>a</span> <span style=''>critical</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>in</span> <span style=''>HTM</span> <span style=''>under</span> <span style=''>a</span> <span style=''>single</span> <span style=''>unifying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>The</span> <span style=''>primary</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanism</span> <span style=''>is</span> <span style=''>explored</span> <span style=''>where</span> <span style=''>a</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determining</span> <span style=''>the</span> <span style=''>degree</span> <span style=''>of</span> <span style=''>permanence</span> <span style=''>update</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>The</span> <span style=''>boosting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mechanisms</span> <span style=''>are</span> <span style=''>studied</span> <span style=''>and</span> <span style=''>found</span> <span style=''>to</span> <span style=''>be</span> <span style=''>only</span> <span style=''>relevant</span> <span style=''>during</span> <span style=''>the</span> <span style=''>initial</span> <span style=''>few</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Observations</s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08333333333333333)
# 	automatic (0.07234042553191489)
# 	knowledge (0.1226950354609929)
# 	segmentation (0.0698581560283688)
# 	processing (0.10815602836879433)
# 	information (0.24148936170212765)
# 	recognition (0.11808510638297873)
# 	detection (0.12659574468085105)
# 	different (0.27163120567375887)
# 	convolutional (0.12872340425531914)
#
# Some Statistics words are:
# 	likelihood (0.10151515151515152)
# 	statistical (0.15151515151515152)
# 	variables (0.13737373737373737)
# 	estimation (0.17323232323232324)
# 	distribution (0.18585858585858586)
# 	theoretical (0.1621212121212121)
# 	algorithm (0.3984848484848485)
# 	dimensional (0.18636363636363637)
# 	inference (0.19343434343434343)
# 	regression (0.18333333333333332)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a2a21e80-d518-4f54-a605-645ec881351a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2a21e80-d518-4f54-a605-645ec881351a")) {                    Plotly.newPlot(                        "a2a21e80-d518-4f54-a605-645ec881351a",                        [{"x":["environment","representation","evolution","emergency","unawareness","efficient","architecture","management","uncertainties","intelligent","monitoring","incidents","prevention","interested","information","classifying","newsgroups","population","categorization","superiority","introduce","conducted","documents","experimentation","significance","occurrence","estimates","particular","unlabeled","comparative","weighting","relevancy","relevance","participation","demonstrate","containing","classification","theoretically","differentiability","algorithms","transform","estimated","difference","convergence","synthesis","performance","iterative","orthonormal","qualitative","convenient","denoising","multivariate","differentiable","sequential","rotations","classical","illustrated","practical","procedure","application","projection","experimentally","estimation","successfully","processing","challenging","framework","convenience","transforms","univariate","interestingness","multidimensional","probability","invertibility","description","covariance","trajectories","complexity","trajectory","selection","observations","characteristics","conditional","computation","fundamental","competitive","experiments","contextual","technique","recovering","applications","discovered","activities","recurrent","unsupervised","representing","collected","different","extensive","generalizability","discovery","competence","structural","undirected","statistics","characterization","environments","characterize","unprecedented","stability","formulate","precision","functions","independent","generalization","projected","interests","dimensional","subspaces","supervised","exploiting","algorithm","optimization","developing","naturally","correlation","optimized","uncertainty","decisions","underlying","outperforms","cumulative","empirically","assumptions","introducing","minimizes","empirical","asymptotic","processes","optimizing","nevertheless","metareasoning","achieving","evaluation","therefore","techniques","retrieving","containment","algorithmic","improvement","experimental","adversely","asymmetric","implement","retrieval","resemblance","estimating","significantly","evaluations","monotonic","transformations","available","traditional","collision","approaches","suboptimal","desirable","theoretical","penalization","literature","comparisons","statistically","advantages","efficiently","inference","variables","combination","regression","nonlinear","computationally","establish","parametric","described","dimensions","generalized","particularities","binarization","segmentation","extraction","applicable","demonstrates","descriptor","identification","extending","heuristics","promising","difficult","restrictive","optimality","computational","continuous","parameters","numerical","relaxations","conditions","certificate","particularly","nonconvex","guarantees","involving","reasonable","switching","commonalities","architectures","arbitrary","considering","deploying","informative","investigation","deployable","generated","questionable","strategies","representations","hypothesis","effective","experiment","intrinsically","bootstrapping","motivated","unbounded","motivation","repertoire","intrinsic","interaction","demonstrations","specifically","demonstration","internally","specialised","respective","distinguish","robustness","limitations","adversarial","vulnerable","influence","divergence","requiring","remaining","direction","attempted" ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	transposable
# 	unpenalized
# 	physiologic
# 	collinearity
# 	permissive
# 	metropolis
# 	correspondingly
# 	parametrizations
# 	negativity
# 	connectome
# 	martingales
# 	equitability
# 	equitable
# 	disproportionately
# 	concavity
# 	tractably
# 	phenotypic
# 	streamline
# 	tractographies
# 	tractography
# Some words which never appear in Statistics papers:
# 	unawareness
# 	relevancy
# 	participation
# 	competence
# 	metareasoning
# 	particularities
# 	inflection
# 	abstracting
# 	illumination
# 	occlusions
# 	assistive
# 	transmitted
# 	neuromorphic
# 	nonmonotonic
# 	phonological
# 	identities
# 	coordinating
# 	metaheuristic
# 	imagination
# 	navigating

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0485016614334054e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7458333333333333
